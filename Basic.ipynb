# %%
import pandas as pd
from clean_data import Data

# %%
data = Data("data/Unprocessed/Fielding/Fielding_ODI.csv")
data.clean()
df = data.df
df
# Out:
#             Player  Mat  Inns  Dis   Ct   St  Ct Wk  Ct Fi           MD  \
# 0    KC Sangakkara  404   397  501  402   99    383     19  5 (4ct 1st)
# 1     AC Gilchrist  287   286  472  417   55    417      0  6 (6ct 0st)
# 2         MS Dhoni  350   345  444  321  123    321      0  6 (5ct 1st)
# 3       MV Boucher  295   291  425  403   22    402      1  6 (6ct 0st)
# 4        Moin Khan  219   217  287  214   73    214      0  5 (5ct 0st)
# ..             ...  ...   ...  ...  ...  ...    ...    ...          ...
# 45         BC Lara  299   296  120  120    0      0    120  3 (3ct 0st)
# 46        L Ronchi   85    83  117  105   12    105      0  4 (4ct 0st)
# 47         MS Wade   94    94  117  108    9    108      0  5 (5ct 0st)
# 48  Inzamam-ul-Haq  378   373  113  113    0      0    113  3 (3ct 0st)
# 49        SR Waugh  325   324  111  111    0      0    111  3 (3ct 0st)
#
#       D/I Country Debut Year Last Match Year
# 0   1.261      SL       2000            2015
# ...

# %%
data.clean()

# %%
data.clean()
df = data.df
df
# Out:
#             Player  Mat  Inns  Dis   Ct   St  Ct Wk  Ct Fi           MD  \
# 0    KC Sangakkara  404   397  501  402   99    383     19  5 (4ct 1st)
# 1     AC Gilchrist  287   286  472  417   55    417      0  6 (6ct 0st)
# 2         MS Dhoni  350   345  444  321  123    321      0  6 (5ct 1st)
# 3       MV Boucher  295   291  425  403   22    402      1  6 (6ct 0st)
# 4        Moin Khan  219   217  287  214   73    214      0  5 (5ct 0st)
# ..             ...  ...   ...  ...  ...  ...    ...    ...          ...
# 45         BC Lara  299   296  120  120    0      0    120  3 (3ct 0st)
# 46        L Ronchi   85    83  117  105   12    105      0  4 (4ct 0st)
# 47         MS Wade   94    94  117  108    9    108      0  5 (5ct 0st)
# 48  Inzamam-ul-Haq  378   373  113  113    0      0    113  3 (3ct 0st)
# 49        SR Waugh  325   324  111  111    0      0    111  3 (3ct 0st)
#
#       D/I Country Debut Year Last Match Year
# 0   1.261      SL       2000            2015
# ...
